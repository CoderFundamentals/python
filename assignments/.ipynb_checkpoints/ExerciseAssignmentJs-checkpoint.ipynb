# %% [markdown]
# Use the data set named Amsterdam.json. This data is about the prices of properties listed on AirBnB. You work for a content marketing company. Your company is doing a story on Amsterdam, one of the components of this report will be about the accessibility of affordable accommodation in the city and about, what factors influence, the prices. Your task is to assist in relevant data analysis. Keeping this context in mind, answer the questions that follow:

# %%
import pandas as pd
import numpy as np

# %%
airbnb_dataset = pd.read_json('amsterdam.json')
airbnb_dataset.head()
# Out:
#    host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                  1.0             6        1.0       2.0                1
# 1                  1.0             2        1.0       1.0                1
# 2                  1.0             2        1.0       1.0                2
# 3                  2.0             4        1.0       2.0                2
# 4                  1.0             2        1.0       1.0                1
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count    price  \
# 0               3                  4                               1  $145.00
# 1               2                 17                               1   $88.00
# 2               2                  4                               1  $130.00
# 3               4                  2                               2  $110.00
# 4               3                 10                               1  $115.00
#
#     latitude  longitude        room_type instant_bookable
# 0  52.361173   4.866755  Entire home/apt                f
# 1  52.370237   4.859507  Entire home/apt                f
# 2  52.362016   4.866872  Entire home/apt                f
# 3  52.365826   4.858178  Entire home/apt                f
# 4  52.364179   4.864885  Entire home/apt                f

# %%
# No of rows in the raw file
no_of_records = airbnb_dataset.shape[0]
no_of_records
# Out:
# 15181

# %%
# Is 'Bathroom' column present in the dataset
column_list = airbnb_dataset.columns.to_list()
query = "Bathroom"
if query in column_list:
    print('column {column} is present in the list'.format(column = query))
else:
    print('column {column} is not present in the list'.format(column = query))
# Out:
# column Bathroom is not present in the list

# %%
#Column named as “bedrooms” has 12 missing values?
missingValues = airbnb_dataset['bedrooms'].isna().sum()
print(' "bedroom" has {count} missing values'.format(count = missingValues))
# Out:
#  "bedroom" has 12 missing values

# %%
airbnb_dataset.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                              object
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# dtype: object

# %%
import re
def removeFormatting(x):
    return float(re.sub("[^\d\.]", "", x))

# %%
#average value of price column
priceList = airbnb_dataset.price.apply(lambda pr: removeFormatting(pr)).to_list()
airbnb_dataset['price'] = priceList
airbnb_dataset.head()
# Out:
#    host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                  1.0             6        1.0       2.0                1
# 1                  1.0             2        1.0       1.0                1
# 2                  1.0             2        1.0       1.0                2
# 3                  2.0             4        1.0       2.0                2
# 4                  1.0             2        1.0       1.0                1
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  price  \
# 0               3                  4                               1  145.0
# 1               2                 17                               1   88.0
# 2               2                  4                               1  130.0
# 3               4                  2                               2  110.0
# 4               3                 10                               1  115.0
#
#     latitude  longitude        room_type instant_bookable
# 0  52.361173   4.866755  Entire home/apt                f
# 1  52.370237   4.859507  Entire home/apt                f
# 2  52.362016   4.866872  Entire home/apt                f
# 3  52.365826   4.858178  Entire home/apt                f
# 4  52.364179   4.864885  Entire home/apt                f

# %%
#calculate the average and max for price
price_avg = sum(priceList)/len(priceList)
price_avg_round = round(price_avg,3)
print("average price round to 3 decimal place is {price}".format(price = price_avg_round))
price_max = round(max(priceList),1)
print("Max price round to 1 decimal place is {price}".format(price = price_max))
# Out:
# average price round to 3 decimal place is 134.799
# Max price round to 1 decimal place is 3142.0

# %%
#AWhat is the 99th percentile in the price column? (Rounded to 1 decimal place, use round
priceList_sorted = sorted(priceList)
percentile_value = round(priceList_sorted[int(len(priceList)*0.99)],1)
print('percentile value round to 1 decimal place is {value}'.format(value = percentile_value))
# Out:
# percentile value round to 1 decimal place is 440.0

# %%
pricelist_refined = [x for x in priceList_sorted if int(x) != 440]
pricelist_refined
#calculate the 90th percentile
percentile_value = round(priceList_sorted[int(len(priceList)*0.90)],1)
print('percentile value round to 1 decimal place is {value}'.format(value = percentile_value))
# Out:
# percentile value round to 1 decimal place is 220.0

# %%
airbnb_dataset.isnull().sum().count
# Out:
# <bound method Series.count of host_listings_count                3
# accommodates                       0
# bathrooms                         18
# bedrooms                          12
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# price                              0
# latitude                           0
# longitude                          0
# room_type                          0
# instant_bookable                   0
# dtype: int64>

# %%
airbnb_dataset.dropna(axis=0, inplace=True)

# %%
airbnb_dataset.isnull().sum().count
# Out:
# <bound method Series.count of host_listings_count               0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# guests_included                   0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# price                             0
# latitude                          0
# longitude                         0
# room_type                         0
# instant_bookable                  0
# dtype: int64>

# %%
airbnb_dataset.shape[0]
# Out:
# 15148

# %%
airbnb_dataset.head()
# Out:
#    host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                  1.0             6        1.0       2.0                1
# 1                  1.0             2        1.0       1.0                1
# 2                  1.0             2        1.0       1.0                2
# 3                  2.0             4        1.0       2.0                2
# 4                  1.0             2        1.0       1.0                1
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  price  \
# 0               3                  4                               1  145.0
# 1               2                 17                               1   88.0
# 2               2                  4                               1  130.0
# 3               4                  2                               2  110.0
# 4               3                 10                               1  115.0
#
#     latitude  longitude        room_type instant_bookable
# 0  52.361173   4.866755  Entire home/apt                f
# 1  52.370237   4.859507  Entire home/apt                f
# 2  52.362016   4.866872  Entire home/apt                f
# 3  52.365826   4.858178  Entire home/apt                f
# 4  52.364179   4.864885  Entire home/apt                f

# %%
def haversine_np(lon1, lat1):
    centrLat = 52.379189
    centrLon = 4.899431
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, centrLon, centrLat])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
airbnb_dataset['d_centre'] = haversine_np(airbnb_dataset['longitude'],airbnb_dataset['latitude'])
airbnb_dataset.head()
# Out:
#    host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                  1.0             6        1.0       2.0                1
# 1                  1.0             2        1.0       1.0                1
# 2                  1.0             2        1.0       1.0                2
# 3                  2.0             4        1.0       2.0                2
# 4                  1.0             2        1.0       1.0                1
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  price  \
# 0               3                  4                               1  145.0
# 1               2                 17                               1   88.0
# 2               2                  4                               1  130.0
# 3               4                  2                               2  110.0
# 4               3                 10                               1  115.0
#
#     latitude  longitude        room_type instant_bookable  d_centre
# 0  52.361173   4.866755  Entire home/apt                f  2.987199
# 1  52.370237   4.859507  Entire home/apt                f  2.885443
# 2  52.362016   4.866872  Entire home/apt                f  2.919191
# 3  52.365826   4.858178  Entire home/apt                f  3.168346
# 4  52.364179   4.864885  Entire home/apt                f  2.876726

# %%
airbnb_dataset.sort_values(by= 'd_centre',
    ascending=True,
    inplace=True,
    kind='quicksort')
airbnb_dataset.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 3158               1                  0                               1
# 3168               1                  0                               1
# 2639               3                 27                               1
# 3010               1                  4                               4
# 1860               1                  9                               1
#
#       price   latitude  longitude        room_type instant_bookable  d_centre
# 3158   85.0  52.378546   4.900775     Private room                f  0.115801
# 3168   41.0  52.378850   4.901433      Shared room                f  0.140946
# 2639  159.0  52.379089   4.897293  Entire home/apt                f  0.145468
# 3010  150.0  52.378549   4.896679     Private room                t  0.199767
# 1860  120.0  52.378398   4.896674     Private room                f  0.206638

# %%
# The average price of Private Rooms that are within 1 km from city centre is (Round to 1 decimal place)

airbnb_dataset_price_avg = airbnb_dataset[airbnb_dataset.d_centre < 1.0]
price_avg = sum(airbnb_dataset_price_avg.price)/airbnb_dataset_price_avg.shape[0]
price_avg_rd = round(price_avg,1)
price_avg_rd
# Out:
# 173.7

# %%
#Create a predictor matrix X, after creating dummies for categorical data. How many columns X will have?
# since price is our target variable we need to drop it
predictor_Y = airbnb_dataset['price']
airbnb_dataset.drop('price', axis = 1, inplace=True)
airbnb_dataset.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 3158               1                  0                               1
# 3168               1                  0                               1
# 2639               3                 27                               1
# 3010               1                  4                               4
# 1860               1                  9                               1
#
#        latitude  longitude        room_type instant_bookable  d_centre
# 3158  52.378546   4.900775     Private room                f  0.115801
# 3168  52.378850   4.901433      Shared room                f  0.140946
# 2639  52.379089   4.897293  Entire home/apt                f  0.145468
# 3010  52.378549   4.896679     Private room                t  0.199767
# 1860  52.378398   4.896674     Private room                f  0.206638

# %%
airbnb_dataset_df = pd.get_dummies(airbnb_dataset)
airbnb_dataset_df.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 3158               1                  0                               1
# 3168               1                  0                               1
# 2639               3                 27                               1
# 3010               1                  4                               4
# 1860               1                  9                               1
#
#        latitude  longitude  d_centre  room_type_Entire home/apt  \
# 3158  52.378546   4.900775  0.115801                          0
# 3168  52.378850   4.901433  0.140946                          0
# 2639  52.379089   4.897293  0.145468                          1
# 3010  52.378549   4.896679  0.199767                          0
# 1860  52.378398   4.896674  0.206638                          0
#
#       room_type_Private room  room_type_Shared room  instant_bookable_f  \
# 3158                       1                      0                   1
# 3168                       0                      1                   1
# 2639                       0                      0                   1
# 3010                       1                      0                   0
# 1860                       1                      0                   1
#
#       instant_bookable_t
# 3158                   0
# 3168                   0
# 2639                   0
# 3010                   1
# 1860                   0

# %%
len(airbnb_dataset_df.columns.to_list())
# Out:
# 16

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(airbnb_dataset_df,predictor_Y,test_size = 0.3, random_state = 200)

# %%
X_train
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 15145                  1.0             4        1.0       1.0
# 9317                   1.0             2        1.5       1.0
# 11850                  1.0             2        1.0       1.0
# 12050                  1.0             2        1.0       1.0
# 7461                   1.0             4        1.0       2.0
# ...                    ...           ...        ...       ...
# 12910                 24.0             3        1.0       1.0
# 14851                  1.0             2        1.5       1.0
# 2012                   1.0             2        1.0       1.0
# 10458                  1.0             2        1.5       1.0
# 7195                   1.0             2        1.0       1.0
#
#        guests_included  minimum_nights  number_of_reviews  \
# 15145                2               2                 35
# 9317                 1               1                  0
# 11850                1               4                  0
# 12050                1               3                  5
# 7461                 1               2                  6
# ...                ...             ...                ...
# 12910                2               1                  2
# 14851                1               1                  2
# 2012                 1               2                 31
# 10458                1               4                  9
# 7195                 2               6                  3
#
#        calculated_host_listings_count   latitude  longitude  d_centre  \
# 15145                               1  52.346686   4.808542  7.147464
# 9317                                1  52.357911   4.903697  2.382220
# 11850                               1  52.365990   4.876936  2.116663
# 12050                               1  52.366140   4.867797  2.590148
# 7461                                1  52.387802   4.882396  1.500376
# ...                               ...        ...        ...       ...
# 12910                              20  52.368927   4.850616  3.502534
# 14851                               1  52.354643   4.828247  5.547079
# 2012                                1  52.376384   4.887006  0.898677
# 10458                               1  52.354485   4.852072  4.226477
# 7195                                1  52.388602   4.886651  1.358524
#
#        room_type_Entire home/apt  room_type_Private room  \
# 15145                          1                       0
# 9317                           1                       0
# 11850                          1                       0
# 12050                          1                       0
# 7461                           1                       0
# ...                          ...                     ...
# 12910                          1                       0
# 14851                          1                       0
# 2012                           1                       0
# 10458                          1                       0
# 7195                           1                       0
#
#        room_type_Shared room  instant_bookable_f  instant_bookable_t
# 15145                      0                   1                   0
# 9317                       0                   1                   0
# 11850                      0                   1                   0
# 12050                      0                   1                   0
# 7461                       0                   1                   0
# ...                      ...                 ...                 ...
# 12910                      0                   1                   0
# 14851                      0                   1                   0
# 2012                       0                   1                   0
# 10458                      0                   1                   0
# 7195                       0                   1                   0
#
# [10603 rows x 16 columns]

# %%
X_test
# Out:
#        host_listings_count  accommodates  bathrooms  bedrooms  \
# 13979                  1.0             3        1.0       2.0
# 2922                   9.0             2        1.0       1.0
# 10694                  1.0             3        1.0       2.0
# 14718                  5.0             2        1.0       1.0
# 3318                   1.0             2        1.0       1.0
# ...                    ...           ...        ...       ...
# 3360                   1.0             3        1.0       2.0
# 13048                  1.0             2        1.0       1.0
# 4310                   1.0             2        2.5       1.0
# 8569                   9.0             1        1.0       1.0
# 507                    1.0             4        1.0       3.0
#
#        guests_included  minimum_nights  number_of_reviews  \
# 13979                1               2                  3
# 2922                 1               3                 31
# 10694                1               1                 20
# 14718                1               5                  7
# 3318                 1               3                  0
# ...                ...             ...                ...
# 3360                 3               3                 14
# 13048                1               2                  0
# 4310                 1               1                  3
# 8569                 1               1                  6
# 507                  4               3                 20
#
#        calculated_host_listings_count   latitude  longitude  d_centre  \
# 13979                               1  52.384198   4.850212  3.384649
# 2922                                8  52.370715   4.885676  1.325733
# 10694                               1  52.354546   4.883988  2.932047
# 14718                               4  52.364143   4.844275  4.098683
# 3318                                1  52.363532   4.935144  2.982963
# ...                               ...        ...        ...       ...
# 3360                                1  52.360866   4.939253  3.383149
# 13048                               1  52.361735   4.865306  3.020362
# 4310                                1  52.364778   4.893575  1.649945
# 8569                                9  52.348466   4.909540  3.482282
# 507                                 1  52.413433   4.884817  3.932336
#
#        room_type_Entire home/apt  room_type_Private room  \
# 13979                          1                       0
# 2922                           1                       0
# 10694                          1                       0
# 14718                          0                       1
# 3318                           1                       0
# ...                          ...                     ...
# 3360                           1                       0
# 13048                          1                       0
# 4310                           0                       1
# 8569                           0                       1
# 507                            1                       0
#
#        room_type_Shared room  instant_bookable_f  instant_bookable_t
# 13979                      0                   1                   0
# 2922                       0                   1                   0
# 10694                      0                   1                   0
# 14718                      0                   1                   0
# 3318                       0                   1                   0
# ...                      ...                 ...                 ...
# 3360                       0                   1                   0
# 13048                      0                   1                   0
# 4310                       0                   1                   0
# 8569                       0                   1                   0
# 507                        0                   1                   0
#
# [4545 rows x 16 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
Regressor = RandomForestRegressor(n_estimators=100,random_state=200,max_features='sqrt')

# %%
Regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_features='sqrt', random_state=200)

# %%
Regressor.predict(X_test)
# Out:
# array([107.2 , 140.91, 135.36, ..., 108.71,  73.83, 190.88])

# %%
Regressor.score(X_test,y_test)
# Out:
# 0.4032890246412547

# %%
param_grid = {  'bootstrap': [True], 'max_features': ['sqrt'], 
              'n_estimators': [30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 170,180, 190, 200,210, 220, 230,
                              240, 250,260,270, 280, 290,300,310,320,330, 340, 350, 360, 370, 380, 390,400, 420, 420, 430,
                              440, 450, 460, 470, 480,490, 500, 520, 520, 530, 540, 550, 560, 570,580,590,600]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
Regressor = RandomForestRegressor(random_state=200,oob_score=True)
gsv = GridSearchCV(estimator= Regressor,param_grid=param_grid,return_train_score=True, verbose=True,n_jobs=-1)
gsv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 58 candidates, totalling 290 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=5)]: Done 290 out of 290 | elapsed: 25.0min finished
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-a4d0542904a9> in <module>
#       2 gsv = GridSearchCV(estimator= Regressor,param_grid=param_grid,return_train_score=True, verbose=True,n_jobs=5)
#       3 gsv.fit(X_train,y_train)
# ----> 4 print(gsv.bestParams_)
#
# AttributeError: 'GridSearchCV' object has no attribute 'bestParams_'

# %%
forest = gsv.best_estimator_

reg_prediction=forest.predict(X_test)

print (gsv.best_score_, gsv.best_params_)
# Out:
# 0.5098202112640473 {'bootstrap': True, 'max_features': 'sqrt', 'n_estimators': 580}

# %%
Regressor_opt = RandomForestRegressor(n_estimators=580,random_state=200,max_features='sqrt')
Regressor_opt.fit(X_test,y_test)
# Out:
# RandomForestRegressor(max_features='sqrt', n_estimators=580, random_state=200)

# %%
featureList = pd.Series(Regressor_opt.feature_importances_, index = airbnb_dataset_df.columns.to_list())

# %%
featureList.sort_values(ascending= False).plot(kind='bar')
# Out:
# <AxesSubplot:>
